# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import random

# ## Input data directory
# data_dir = "cureus"
# inputdirectory = Path(f"./data_input/{data_dir}")
# ## This is where the output csv files will be written
# out_dir = data_dir
# outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
df = pd.read_csv("Birds Data.csv", index_col = 'Unnamed: 0')
df.head()
# Out:
#                   Species                 eBird Link  \
# 1             Rock Pigeon   /species/rocpig/IN-PB-SH
# 2  Eurasian Collared-Dove   /species/eucdov/IN-PB-SH
# 3           Laughing Dove  /species/laudov1/IN-PB-SH
# 4              Black Kite  /species/blakit1/IN-PB-SH
# 5    Rose-ringed Parakeet   /species/rorpar/IN-PB-SH
#
#                                                 Info
# 1  Fairly large pigeon with wild and feral popula...
# 2  Large pale dove with a black crescent on the n...
# 3  Small, similar in size to European Turtle-Dove...
# 4  Medium-sized, rather nondescript raptor with o...
# 5  Vibrantly bright green parakeet, frequently fo...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document

# Initialize a list to store the document objects
documents = []

# Combine the relevant columns into a single text string for each row and create Document objects
for index, row in df.iterrows():
    content = f"Species: {row['Species']}\n"
    content += f"Info: {row['Info']}\n"
    documents.append(Document(page_content=content))

# Initialize the text splitter
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

# Split the documents into chunks
chunks = splitter.split_documents(documents)

# Output the chunks
print("Number of chunks =", len(chunks))
# Out:
# Number of chunks = 351

# %%
print(f"Chunk:")
print(chunks[0].page_content)
# Out:
# Chunk:
# Species: Rock Pigeon
# Info: Fairly large pigeon with wild and feral populations throughout the world. True wild birds nest on cliffs and in caves from western Europe to central Asia. Pale gray overall with two bold black wingbars and iridescent purple and green on neck. Feral varieties are common in cities and farmland, often in large flocks. Variable plumage: some identical to wild-type birds, but can be completely black, white, or orangey-brown and any combination in between.

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(chunks)
print(df.shape)
df.head()
# Out:
# (351, 2)
#                                                 text  \
# 0  Species: Rock Pigeon\nInfo: Fairly large pigeo...
# 1  Species: Eurasian Collared-Dove\nInfo: Large p...
# 2  Species: Laughing Dove\nInfo: Small, similar i...
# 3  Species: Black Kite\nInfo: Medium-sized, rathe...
# 4  Species: Rose-ringed Parakeet\nInfo: Vibrantly...
#
#                            chunk_id
# 0  5bbd095cd23f4130a6d672640d5b83eb
# 1  b2759167891e430da492381acb859f56
# 2  00beb63d4e7145efa09c11aec218c9ec
# 3  0d64fb5953ac4becba9fafbce9434980
# 4  d861ec9a63df40f2a917cfb3f49b79ed

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
outputdirectory = Path("./data_output")

# %%
df = df.loc[5:100]

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='mistral:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph2.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks2.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# An error occurred: 500 Server Error: Internal Server Error for url: http://localhost:11434/api/generate
#
#
# ERROR ### Here is the buggy response:  None
#
#
#  [
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "warblerlike bird",
#        "edge": "The Common Tailorbird is a warblerlike bird."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "green back",
#        "edge": "The Common Tailorbird has a green back."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "reddish crown",
#        "edge": "The Common Tailorbird has a reddish crown."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "long bill",
#        "edge": "The Common Tailorbird has a long bill."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "parks, gardens, and wooded areas",
#        "edge": "The Common Tailorbird is an inhabitant of parks, gardens, and wooded areas."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "South and Southeast Asia",
#        "edge": "The Common Tailorbird is ubiquitous in South and Southeast Asia."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "its name",
#        "edge": "The Common Tailorbird gets its name from the way it builds its nest by stitching leaves together."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "loud ‘tuui-tuui…’ and ‘whee-whee…’ calls",
#        "edge": "The loud ‘tuui-tuui…’ and ‘whee-whee…’ calls are often part of the sound of daily life in human habitation."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "Dark-necked Tailorbird",
#        "edge": "The Common Tailorbird co-occurs with the Dark-necked Tailorbird in NE India and SE Asia."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "call",
#        "edge": "The Common Tailorbird is separable from the Dark-necked Tailorbird by call."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "rufous hind-crown",
#        "edge": "The Common Tailorbird can be separable from the Dark-necked Tailorbird by the lack of a rufous hind-crown."
#    },
#    {
#        "node_1": "Common Tailorbird",
#        "node_2": "yellow vent",
#        "edge": "The Common Tailorbird can be separable from the Dark-necked Tailorbird by the lack of a yellow vent."
#    }
# ] [
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Bird",
#        "edge": "The Red-vented Bulbul is a medium-sized bird."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Dark",
#        "edge": "The Red-vented Bulbul has a dark coloration."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Sleek",
#        "edge": "The Red-vented Bulbul is described as sleek."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Black crest",
#        "edge": "The Red-vented Bulbul has a black crest."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "White rump",
#        "edge": "The white rump of the Red-vented Bulbul is often difficult to see."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Eats fruit, flower buds, and insects",
#        "edge": "The Red-vented Bulbul eats fruit, flower buds, and insects."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Conspicuous",
#        "edge": "The Red-vented Bulbul is conspicuous."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Gregarious",
#        "edge": "The Red-vented Bulbul can be gregarious."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Urban and rural areas",
#        "edge": "The Red-vented Bulbul is often seen in urban and rural areas."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Scrubby edge habitat",
#        "edge": "The Red-vented Bulbul prefers scrubby edge habitat instead of dense forest."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Calls include a variety of chirps and whistles",
#        "edge": "The Red-vented Bulbul calls include a variety of chirps and whistles."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "South and Southeast Asia",
#        "edge": "The Red-vented Bulbul is native to South and Southeast Asia."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Kuwait, Qatar, United Arab Emirates, Oman",
#        "edge": "The Red-vented Bulbul has been introduced to Kuwait, Qatar, United Arab Emirates, and Oman."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Some Polynesian islands",
#        "edge": "The Red-vented Bulbul has been introduced to some Polynesian islands."
#    },
#    {
#        "node_1": "Red-vented Bulbul",
#        "node_2": "Hawaii",
#        "edge": "The Red-vented Bulbul has been introduced to Hawaii."
#    }
# ] [
#    {
#        "node_1": "Common Chiffchaff",
#        "node_2": "Species",
#        "edge": "The Common Chiffchaff is a species of bird."
#    },
#    {
#        "node_1": "Common Chiffchaff",
#        "node_2": "Leaf warbler",
#        "edge": "The Common Chiffchaff is a type of leaf warbler."
#    },
#    {
#        "node_1": "Common Chiffchaff",
#        "node_2": "Found in wooded and scrubby habitats",
#        "edge": "The Common Chiffchaff can be found in wooded and scrubby habitats."
#    },
#    {
#        "node_1": "Common Chiffchaff",
#        "node_2": "Often near water",
#        "edge": "The Common Chiffchaff is often found near water."
#    },
#    {
#        "node_1": "Song of the Common Chiffchaff",
#        "node_2": "Chiff-chaff...",
#        "edge": "The song of the Common Chiffchaff is a slightly jerky double-noted chiff-chaff, chiff-chaff..."
#    },
#    {
#        "node_1": "Song of the Common Chiffchaff",
#        "node_2": "Very different from song of the Willow Warbler",
#        "edge": "The song of the Common Chiffchaff is very different from the song of the Willow Warbler."
#    },
#    {
#        "node_1": "Relative to Willow Warbler",
#        "node_2": "Chiffchaff",
#        "edge": "Compared to the Willow Warbler, the Chiffchaff is often duller, more brownish overall with weaker pale eyebrow, dark legs, and tends to habitually dip its tail."
#    },
#    {
#        "node_1": "Booted and Sykes’s Warbler",
#        "node_2": "Similar to Common Chiffchaff",
#        "edge": "The Common Chiffchaff is similar to Booted and Sykes’s Warbler, but these are browner toned with darkish legs and bill."
#    }
# ] [
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "ash-brown colored babbler",
#        "edge": "The Jungle Babbler is referred to as an ash-brown colored babbler."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "yellow bill",
#        "edge": "The Jungle Babbler has a yellow bill."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "dark brow in front of the eye",
#        "edge": "The Jungle Babbler has a dark brow in front of its eye."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "pale eye",
#        "edge": "The Jungle Babbler's eye is described as pale."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "perpetual ‘angry’ look",
#        "edge": "The contrast between the Jungle Babbler's dark brow and its pale eye gives it a perpetual 'angry' look."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "vue streaking on the upperparts",
#        "edge": "The Jungle Babbler has vague streaking on its upperparts."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "diffuse mottling on its throat",
#        "edge": "The Jungle Babbler has diffuse mottling on its throat."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "barring on its tail",
#        "edge": "The Jungle Babbler has barring on its tail."
#    },
#    {
#        "node_1": "race somervillei",
#        "node_2": "Jungle Babbler",
#        "edge": "The race somervillei of the NW peninsula is a variant of the Jungle Babbler."
#    },
#    {
#        "node_1": "race somervillei",
#        "node_2": "dark brown outer wing feathers",
#        "edge": "The race somervillei of the Jungle Babbler has dark brown outer wing feathers that contrast with the rest of the wing."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "noisy flocks hopping on the ground",
#        "edge": "The Jungle Babbler is often seen in noisy flocks hopping on the ground."
#    },
#    {
#        "node_1": "Jungle Babbler",
#        "node_2": "flicking litter in search of food",
#        "edge": "While hopping on the ground, the Jungle Babbler often flicks litter in search of food."
#    }
# ] [
#    {
#        "node_1": "Common Myna",
#        "node_2": "Species",
#        "edge": "The Common Myna is a species."
#    },
#    {
#        "node_1": "Common Myna",
#        "node_2": "Large",
#        "edge": "The Common Myna is described as large."
#    },
#    {
#        "node_1": "Common Myna",
#        "node_2": "Black-and-brown",
#        "edge": "The Common Myna has a black-and-brown coloring."
#    },
#    {
#        "node_1": "Common Myna",
#        "node_2": "White wing patches",
#        "edge": "The Common Myna has white patches on its wings."
#    },
#    {
#        "node_1": "Common Myna",
#        "node_2": "Yellow bill",
#        "edge": "The Common Myna has a yellow bill."
#    },
#    {
#        "node_1": "Common Myna",
#        "node_2": "Yellow legs",
#        "edge": "The Common Myna has yellow legs."
#    },
#    {
#        "node_1": "Gregarious",
#        "node_2": "Common Myna",
#        "edge": "The Common Myna is gregarious, often found in noisy flocks."
#    },
#    {
#        "node_1": "Aggressive",
#        "node_2": "Common Myna",
#        "edge": "The Common Myna is aggressive, often driving away other birds."
#    },
#    {
#        "node_1": "Can be found just about anywhere",
#        "node_2": "Common Myna",
#        "edge": "The Common Myna can be found in various locations, except the densest forests."
#    },
#    {
#        "node_1": "Southern Asia",
#        "node_2": "Native to",
#        "edge": "The Common Myna is native to southern Asia."
#    },
#    {
#        "node_1": "Among the most common species",
#        "node_2": "In southern Asia",
#        "edge": "In southern Asia, the Common Myna is among the most common species."
#    },
#    {
#        "node_1": "Widely introduced",
#        "node_2": "Common Myna",
#        "edge": "The Common Myna has been widely introduced elsewhere in the world."
#    },
#    {
#        "node_1": "Australia",
#        "node_2": "Where it is widely introduced",
#        "edge": "The Common Myna has been widely introduced to Australia."
#    },
#    {
#        "node_1": "New Zealand",
#        "node_2": "Where it is widely introduced",
#        "edge": "The Common Myna has been widely introduced to New Zealand."
#    },
#    {
#        "node_1": "Hawaii",
#        "node_2": "Where it is widely introduced",
#        "edge": "The Common Myna has been widely introduced to Hawaii."
#    }
# ] [
#     {
#         "node_1": "Brown Rock Chat",
#         "node_2": "Species",
#         "edge": "The Brown Rock Chat is a species of bird."
#     },
#     {
#         "node_1": "Plain chocolate-brown chat",
#         "node_2": "Alternate Name",
#         "edge": "The Plain chocolate-brown chat is another name for the Brown Rock Chat."
#     },
#     {
#         "node_1": "Ridges, cliff edges, and buildings",
#         "node_2": "Habitat",
#         "edge": "Brown Rock Chats are often seen on ridges, cliff edges, and buildings, suggesting these areas as their habitats."
#     },
#     {
#         "node_1": "Female Indian Robin",
#         "node_2": "Similar Species",
#         "edge": "The female Indian Robin can be somewhat similar to the Brown Rock Chat."
#     },
#     {
#         "node_1": "Brown Rock Chat",
#         "node_2": "Female Indian Robin",
#         "edge": "However, it's important to note that a Brown Rock Chat has a proportionally shorter tail and lacks a rufous vent compared to the female Indian Robin."
#     },
#     {
#         "node_1": "Brown Rock Chat",
#         "node_2": "Physical Characteristics",
#         "edge": "The Brown Rock Chat is characterized by its plain chocolate-brown color, tall and proud posture, shorter tail, and lack of a rufous vent."
#     },
#     {
#         "node_1": "Lovely song",
#         "node_2": "Characteristic",
#         "edge": "The Brown Rock Chat is known for its lovely song which is composed of warbles and trills."
#     },
#     {
#         "node_1": "Warbles and trills",
#         "node_2": "Components of Song",
#         "edge": "The lovely song of the Brown Rock Chat consists of warbles and trills."
#     },
#     {
#         "node_1": "Chee",
#         "node_2": "Common Call",
#         "edge": "The most common call of the Brown Rock Chat is a slightly descending ‘chee’."
#     }
# ] [
#    {
#        "node_1": "Bar-headed Goose",
#        "node_2": "Species",
#        "edge": "The Bar-headed Goose is a species."
#    },
#    {
#        "node_1": "Striking and distinctive goose",
#        "node_2": "Bar-headed Goose",
#        "edge": "The Bar-headed Goose is described as striking and distinctive."
#    },
#    {
#        "node_1": "Bold black-and-white head and neck pattern",
#        "node_2": "Bar-headed Goose",
#        "edge": "The Bar-headed Goose has a bold black-and-white head and neck pattern."
#    },
#    {
#        "node_1": "Orangey-yellow bill",
#        "node_2": "Bar-headed Goose",
#        "edge": "The Bar-headed Goose has an orangey-yellow bill."
#    },
#    {
#        "node_1": "Legs",
#        "node_2": "Bar-headed Goose",
#        "edge": "The Bar-headed Goose has legs, which are also described as orangey-yellow."
#    },
#    {
#        "node_1": "Pale gray",
#        "node_2": "Bar-headed Goose (in flight)",
#        "edge": "When in flight, the Bar-headed Goose appears mainly pale gray."
#    },
#    {
#        "node_1": "Broad black trailing edge to wings",
#        "node_2": "Bar-headed Goose (in flight)",
#        "edge": "When in flight, the Bar-headed Goose has a broad black trailing edge to its wings."
#    },
#    {
#        "node_1": "Lakes and marshes on highland plateaus",
#        "node_2": "Breeds",
#        "edge": "The Bar-headed Goose breeds around lakes and marshes on highland plateaus."
#    },
#    {
#        "node_1": "Lowland wetlands and fields",
#        "node_2": "Winters",
#        "edge": "The Bar-headed Goose winters in lowland wetlands and fields."
#    },
#    {
#        "node_1": "East and South Asia",
#        "node_2": "Native to",
#        "edge": "The Bar-headed Goose is native to East and South Asia."
#    },
#    {
#        "node_1": "Waterfowl collections",
#        "node_2": "Native to",
#        "edge": "Although native to East and South Asia, the Bar-headed Goose has been seen free-flying elsewhere in the world due to escapees from waterfowl collections."
#    }
# ] [
#    {
#        "node_1": "Graylag Goose",
#        "node_2": "Large",
#        "edge": "The Graylag Goose is a large gray goose."
#    },
#    {
#        "node_1": "Graylag Goose",
#        "node_2": "Brownish gray",
#        "edge": "The Graylag Goose has an overall brownish gray appearance."
#    },
#    {
#        "node_1": "Graylag Goose",
#        "node_2": "Big pinkish-orange bill",
#        "edge": "The Graylag Goose has a big pinkish-orange bill."
#    },
#    {
#        "node_1": "Graylag Goose",
#        "node_2": "Pinkish legs",
#        "edge": "The Graylag Goose has pinkish legs."
#    },
#    {
#        "node_1": "In flight",
#        "node_2": "Extensively pale gray leading edge to upperwings",
#        "edge": "When the Graylag Goose is in flight, it shows an extensively pale gray leading edge to its upperwings."
#    },
#    {
#        "node_1": "In flight",
#        "node_2": "Pale underwing coverts",
#        "edge": "When the Graylag Goose is in flight, it has pale underwing coverts."
#    },
#    {
#        "node_1": "In flight",
#        "node_2": "Broad white tail tip",
#        "edge": "When the Graylag Goose is in flight, it has a broad white tail tip."
#    },
#    {
#        "node_1": "Comparison",
#        "node_2": "Graylag Goose",
#        "edge": "The Graylag Goose can be compared to other gray geese that differ in details of bill pattern and color, head and neck pattern, and have dark underwings."
#    },
#    {
#        "node_1": "Inhabits",
#        "node_2": "Lakes, marshes, and wetlands",
#        "edge": "The Graylag Goose inhabits lakes, marshes, and wetlands."
#    },
#    {
#        "node_1": "European range",
#        "node_2": "Urban parks",
#        "edge": "In parts of its European range, the Graylag Goose can be found in urban parks."
#    }
# ] [
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Waterbird",
#        "edge": "The Knob-billed Duck is a type of waterbird."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Species",
#        "edge": "The Knob-billed Duck is a species."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Large",
#        "edge": "The Knob-billed Duck is large in size."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Bicolored",
#        "edge": "The Knob-billed Duck has a bicolor appearance."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Iridescent",
#        "edge": "The upper part of the Knob-billed Duck's body is iridescent purplish-green."
#    },
#    {
#        "node_1": "Knob-billed Duck (male)",
#        "node_2": "Iridescent",
#        "edge": "The male Knob-billed Duck has an iridescent upper part."
#    },
#    {
#        "node_1": "Knob-billed Duck (male)",
#        "node_2": "Black lump",
#        "edge": "Males of the Knob-billed Duck have a large black lump on their bill."
#    },
#    {
#        "node_1": "Knob-billed Duck (female)",
#        "node_2": "Plain bill",
#        "edge": "Females of the Knob-billed Duck have a plain bill."
#    },
#    {
#        "node_1": "Knob-billed Duck (female)",
#        "node_2": "Gray flanks",
#        "edge": "Females of the Knob-billed Duck have gray flanks."
#    },
#    {
#        "node_1": "Knob-billed Duck (male)",
#        "node_2": "Gray flanks",
#        "edge": "Males of the Knob-billed Duck have gray flanks, but with a whitish belly."
#    },
#    {
#        "node_1": "Knob-billed Duck (male)",
#        "node_2": "Whitish belly",
#        "edge": "Males of the Knob-billed Duck have a whitish belly."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Buffy breast",
#        "edge": "The breast of the Knob-billed Duck is white or buffy."
#    },
#    {
#        "node_1": "Knob-billed Duck (female)",
#        "node_2": "Plain bill",
#        "edge": "Females of the Knob-billed Duck do not have a large black lump on their bill."
#    },
#    {
#        "node_1": "Knob-billed Duck (female)",
#        "node_2": "Gray flanks",
#        "edge": "Females of the Knob-billed Duck have gray flanks, unlike males which have gray flanks and a whitish belly."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "India",
#        "edge": "The Knob-billed Duck occurs in India."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Africa",
#        "edge": "The Knob-billed Duck occurs throughout much of Africa."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Southeast Asia",
#        "edge": "The Knob-billed Duck occurs in Southeast Asia."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Freshwater rivers, lakes, and marshes",
#        "edge": "The Knob-billed Duck is found in freshwater rivers, lakes, and marshes."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Uncommon",
#        "edge": "The Knob-billed Duck is usually uncommon."
#    },
#    {
#        "node_1": "Knob-billed Duck",
#        "node_2": "Normally silent",
#        "edge": "The Knob-billed Duck is normally silent."
#    },
#    {
#        "node_1": "Knob-billed Duck (wings)",
#        "node_2": "Dark",
#        "edge": "All the wings of the Knob-billed Duck are dark."
#    }
# ] [
#     {
#         "node_1": "Northern Shoveler",
#         "node_2": "Species",
#         "edge": "The Northern Shoveler is a species of duck."
#     },
#     {
#         "node_1": "Northern Shoveler",
#         "node_2": "Medium-sized",
#         "edge": "The Northern Shoveler is medium-sized, smaller than a Mallard."
#     },
#     {
#         "node_1": "Northern Shoveler",
#         "node_2": "Mallard",
#         "edge": "The Northern Shoveler is smaller than a Mallard."
#     },
#     {
#         "node_1": "Huge, spoon-shaped bill",
#         "node_2": "Northern Shoveler",
#         "edge": "The Northern Shoveler has a huge, spoon-shaped bill which can be visible at a distance and in flight."
#     },
#     {
#         "node_1": "Breeding males",
#         "node_2": "Northern Shoveler",
#         "edge": "During breeding, the male Northern Shoveler has a dark green head, white breast, chestnut sides and belly."
#     },
#     {
#         "node_1": "Females",
#         "node_2": "Northern Shoveler",
#         "edge": "The female Northern Shoveler is buffy-brown with a large, distinctive bill."
#     },
#     {
#         "node_1": "Chalky-blue upperwing",
#         "node_2": "Northern Shoveler",
#         "edge": "The Northern Shoveler has a chalky-blue upperwing."
#     },
#     {
#         "node_1": "Forages by sifting through the water",
#         "node_2": "Northern Shoveler",
#         "edge": "The Northern Shoveler forages by sifting through the water."
#     },
#     {
#         "node_1": "Swimming in spirals in groups",
#         "node_2": "Foraging behavior of Northern Shoveler",
#         "edge": "While foraging, the Northern Shoveler often swims in spirals in groups."
#     }
# ] [
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Species",
#        "edge": "The Indian Spot-billed Duck is a species of duck."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Large grayish-brown",
#        "edge": "The Indian Spot-billed Duck is large and has a grayish-brown color."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Yellow-tipped black bill",
#        "edge": "The Indian Spot-billed Duck has a yellow-tipped black bill."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Red spot at the base of the bill",
#        "edge": "In some Indian Spot-billed Ducks, there is a red spot at the base of the bill."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Green panel in the wing",
#        "edge": "The Indian Spot-billed Duck has a green panel in its wing."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "White border in the green panel",
#        "edge": "The green panel in the Indian Spot-billed Duck's wing is bordered in white."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Often seen in small groups",
#        "edge": "The Indian Spot-billed Ducks are often seen in small groups."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Shallow water",
#        "edge": "The Indian Spot-billed Ducks are often seen dabbling or tipping up in shallow water."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Marshy land",
#        "edge": "The Indian Spot-billed Ducks are often seen walking on marshy land."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Edge of freshwater lakes",
#        "edge": "The Indian Spot-billed Ducks are often seen at the edge of freshwater lakes."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Cultivated fields",
#        "edge": "The Indian Spot-billed Ducks are often seen in cultivated fields."
#    },
#    {
#        "node_1": "Indian Spot-billed Duck",
#        "node_2": "Usually not seen associating with other species",
#        "edge": "The Indian Spot-billed Ducks usually do not associate with other species."
#    },
#    {
#        "node_1": "Eastern Spot-billed Duck",
#        "node_2": "Similar to Eastern Spot-billed Duck",
#        "edge": "The Indian Spot-billed Duck is similar to the Eastern Spot-billed Duck."
#    },
#    {
#        "node_1": "Eastern Spot-billed Duck",
#        "node_2": "Note green wing panel",
#        "edge": "When comparing with the Eastern Spot-billed Duck, note the green wing panel of the Indian Spot-billed Duck."
#    },
#    {
#        "node_1": "Eastern Spot-billed Duck",
#        "node_2": "Lack of a distinct dark 'moustache'",
#        "edge": "When comparing with the Eastern Spot-billed Duck, note the lack of a distinct dark 'moustache' in the Indian Spot-billed Duck."
#    },
#    {
#        "node_1": "Eastern Spot-billed Duck",
#        "node_2": "Overall warmer tan coloration",
#        "edge": "When comparing with the Eastern Spot-billed Duck, note the overall warmer tan coloration of the Indian Spot-billed Duck."
#    }
# ] [
#    {
#        "node_1": "Green-winged Teal",
#        "node_2": "Species",
#        "edge": "The Green-winged Teal is a species of duck."
#    },
#    {
#        "node_1": "Tiny duck",
#        "node_2": "Green-winged Teal",
#        "edge": "The Green-winged Teal is described as a tiny duck in the context."
#    },
#    {
#        "node_1": "Petite, thin bill",
#        "node_2": "Green-winged Teal",
#        "edge": "The Green-winged Teal has a petite, thin bill."
#    },
#    {
#        "node_1": "Brown head",
#        "node_2": "Male Green-winged Teal",
#        "edge": "Males of the Green-winged Teal have a brown head."
#    },
#    {
#        "node_1": "Green swatch",
#        "node_2": "Male Green-winged Teal",
#        "edge": "The males of the Green-winged Teal have a wide green swatch behind the eye."
#    },
#    {
#        "node_1": "Creamy speckled breast",
#        "node_2": "Male Green-winged Teal",
#        "edge": "The males of the Green-winged Teal have a creamy speckled breast."
#    },
#    {
#        "node_1": "Gray body",
#        "node_2": "Male Green-winged Teal",
#        "edge": "The males of the Green-winged Teal have mostly gray bodies."
#    },
#    {
#        "node_1": "Brown",
#        "node_2": "Female Green-winged Teal",
#        "edge": "Females of the Green-winged Teal are brown."
#    },
#    {
#        "node_1": "Darker overall",
#        "node_2": "Female Green-winged Teal",
#        "edge": "Females of the Green-winged Teal are darker overall than other dabbling ducks."
#    },
#    {
#        "node_1": "Dabbling ducks",
#        "node_2": "Other dabbling ducks",
#        "edge": "The females of the Green-winged Teal are compared to 'other dabbling ducks' in terms of darkness."
#    },
#    {
#        "node_1": "Submerged aquatic vegetation",
#        "node_2": "Forages by dabbling",
#        "edge": "The Green-winged Teal forages by dabbling and reaches submerged aquatic vegetation."
#    },
#    {
#        "node_1": "Mudflats",
#        "node_2": "Also regularly walks around",
#        "edge": "In addition to dabbling, the Green-winged Teal also regularly walks around mudflats to feed."
#    }
# ] [
#     {
#        "node_1": "Little Grebe",
#        "node_2": "Species",
#        "edge": "The Little Grebe is a species of bird."
#     },
#     {
#        "node_1": "Wetlands",
#        "node_2": "Habitat",
#        "edge": "The Little Grebe lives in wetlands with bordering reeds and other vegetation."
#     },
#     {
#        "node_1": "Open water",
#        "node_2": "Habitat",
#        "edge": "The Little Grebe is sometimes seen on open water, mainly during winter."
#     },
#     {
#        "node_1": "Rounded head",
#        "node_2": "Physical Characteristics",
#        "edge": "The Little Grebe has a rounded head."
#     },
#     {
#        "node_1": "Puffy rear end",
#        "node_2": "Physical Characteristics",
#        "edge": "The Little Grebe has a puffy rear end."
#     },
#     {
#        "node_1": "Singles and small loose flocks",
#        "node_2": "Group Behavior",
#        "edge": "The Little Grebe is usually seen as singles or small groups."
#     },
#     {
#        "node_1": "Daytime sleeping",
#        "node_2": "Behavior",
#        "edge": "The Little Grebe often sleeps during the day."
#     },
#     {
#        "node_1": "Dark rusty head and neck sides with yellow patch at base of bill",
#        "node_2": "Breeding Plumage",
#        "edge": "During breeding, the Little Grebe can appear dark overall with a dark rusty head and neck sides and a yellow patch at the base of the bill."
#     },
#     {
#        "node_1": "Dingy pale brownish overall with dark cap",
#        "node_2": "Non-breeding Plumage",
#        "edge": "In non-breeding plumage, the Little Grebe is dingy pale brownish overall with a dark cap."
#     }
# ] [
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Large bird",
#        "edge": "The Greater Coucal is a large bird."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Crow",
#        "edge": "The Greater Coucal resembles a crow in appearance."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Pheasant",
#        "edge": "The Greater Coucal resembles a pheasant in appearance."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Black color",
#        "edge": "The Greater Coucal is largely black."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Rusty wings",
#        "edge": "The Greater Coucal has distinctive rusty wings."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Glossy underparts",
#        "edge": "The underparts of the Greater Coucal are glossy."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Long and heavy black tail",
#        "edge": "The Greater Coucal has a long and heavy black tail."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Deep red eyes",
#        "edge": "The Greater Coucal has deep red eyes."
#    },
#    {
#        "node_1": "Juvenile Greater Coucal",
#        "node_2": "White bars on the tail",
#        "edge": "Juvenile Greater Coucals have white bars on their tails."
#    },
#    {
#        "node_1": "Juvenile Greater Coucal",
#        "node_2": "Underparts",
#        "edge": "Juvenile Greater Coucals have duller underparts."
#    },
#    {
#        "node_1": "Juvenile Greater Coucal",
#        "node_2": "Black streaks on the wings and upperparts",
#        "edge": "Juvenile Greater Coucals have variable amounts of black streaks on their wings and upperparts."
#    },
#    {
#        "node_1": "Adult Greater Coucal",
#        "node_2": "Lacks the white streaks on the wings seen on Lesser Coucal",
#        "edge": "Adult Greater Coucals lack the white streaks on the wings that are present in Lesser Coucals."
#    },
#    {
#        "node_1": "Greater Coucal",
#        "node_2": "Lesser Coucal",
#        "edge": "The Greater Coucal is similar to the Lesser Coucal, but it is larger with a longer bill and red eyes."
#    },
#    {
#        "node_1": "Adult Greater Coucal",
#        "node_2": "Resonant ‘oop-oop-oop’ notes",
#        "edge": "The call of an adult Greater Coucal is a series of deep, resonant 'oop-oop-oop' notes."
#    }
# ] [
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Medium-sized",
#        "edge": "The White-breasted Waterhen is a medium-sized bird."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Chickenlike marsh bird",
#        "edge": "The White-breasted Waterhen is often referred to as a chickenlike marsh bird due to its appearance and habitat."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Found in meadows, ditches, riversides, marshes, parks, farmlands",
#        "edge": "The White-breasted Waterhen can be found in various environments including meadows, ditches, riversides, marshes, parks, and farmlands."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Close proximity to humans",
#        "edge": "The White-breasted Waterhen is often found in close proximity to human habitats such as parks and farmlands."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Often seen foraging in the open",
#        "edge": "The White-breasted Waterhen is often observed foraging in open areas."
#    },
#    {
#        "node_1": "Adult White-breasted Waterhen",
#        "node_2": "Dark slaty above and white below",
#        "edge": "Adult White-breasted Waterhens are dark slaty above and white below."
#    },
#    {
#        "node_1": "Adult White-breasted Waterhen",
#        "node_2": "Rusty patch under the tail",
#        "edge": "Adult White-breasted Waterhens have a rusty patch under their tail."
#    },
#    {
#        "node_1": "Juvenile White-breasted Waterhen",
#        "node_2": "Duller in color",
#        "edge": "Juvenile White-breasted Waterhens are duller in color compared to adults."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Remarkably variable song",
#        "edge": "The White-breasted Waterhen has a remarkably variable song which can be a series of hooting, grunting, or rasping notes or phrases."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "Repeated monotonously",
#        "edge": "The White-breasted Waterhen's song is often repeated monotonously."
#    },
#    {
#        "node_1": "White-breasted Waterhen",
#        "node_2": "From an exposed perch",
#        "edge": "The White-breasted Waterhen often sings from an exposed perch."
#    }
# ] [
#    {
#        "node_1": "Black-winged Stilt",
#        "node_2": "Species",
#        "edge": "The Black-winged Stilt is a species of bird."
#    },
#    {
#        "node_1": "Striking large black-and-white wader",
#        "node_2": "Black-winged Stilt",
#        "edge": "The Black-winged Stilt is described as a striking, large black-and-white bird."
#    },
#    {
#        "node_1": "thin, straight bill",
#        "node_2": "Black-winged Stilt",
#        "edge": "The Black-winged Stilt has a thin, straight bill."
#    },
#    {
#        "node_1": "bright pink legs",
#        "node_2": "Black-winged Stilt",
#        "edge": "The Black-winged Stilt has bright pink legs."
#    },
#    {
#        "node_1": "wetlands with open shallow water",
#        "node_2": "Habitat of Black-winged Stilt",
#        "edge": "The Black-winged Stilt is found in wetlands with open shallow water."
#    },
#    {
#        "node_1": "brackish habitats",
#        "node_2": "Habitat of Black-winged Stilt",
#        "edge": "The Black-winged Stilt often inhabits brackish habitats."
#    },
#    {
#        "node_1": "northerly breeding grounds",
#        "node_2": "Migration pattern of Black-winged Stilt",
#        "edge": "Some populations of the Black-winged Stilt depart from their northerly breeding grounds for warmer southern regions."
#    },
#    {
#        "node_1": "warm southern regions",
#        "node_2": "Migration pattern of Black-winged Stilt",
#        "edge": "The Black-winged Stilt migrates to warmer southern regions during some periods."
#    },
#    {
#        "node_1": "bare ground near water",
#        "node_2": "Habitat and colony of Black-winged Stilt",
#        "edge": "The Black-winged Stilt often forms noisy colonies on bare ground near water."
#    },
#    {
#        "node_1": "Southeast Asia",
#        "node_2": "Region of comparison for Black-winged Stilt",
#        "edge": "In parts of Southeast Asia, the Black-winged Stilt is compared with the Pied Stilt."
#    },
#    {
#        "node_1": "Pied Stilt",
#        "node_2": "Comparable species to Black-winged Stilt",
#        "edge": "In parts of Southeast Asia, the Pied Stilt is a comparable species to the Black-winged Stilt."
#    },
#    {
#        "node_1": "needle-like bill",
#        "node_2": "Black-winged Stilt",
#        "edge": "The Black-winged Stilt feeds by wading in water, picking from the water surface with its needle-like bill."
#    },
#    {
#        "node_1": "flight",
#        "node_2": "Observable activity of Black-winged Stilt",
#        "edge": "In flight, the long pink legs of the Black-winged Stilt stick out far beyond the tail."
#    },
#    {
#        "node_1": "loudly and stridently",
#        "node_2": "Calling behavior of Black-winged Stilt",
#        "edge": "The Black-winged Stilt calls loudly and stridently, especially when alarmed during the breeding season."
#    },
#    {
#        "node_1": "breeding season",
#        "node_2": "Behavioral context of calling in Black-winged Stilt",
#        "edge": "The Black-winged Stilt calls loudly and stridently, especially during the breeding season."
#    }
# ] [
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Distinctly marked lapwing",
#        "edge": "The Red-wattled Lapwing is a distinctly marked lapwing."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Black breast and throat",
#        "edge": "The Red-wattled Lapwing has a black breast and throat."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Red bill with black tip",
#        "edge": "The Red-wattled Lapwing has a red bill with a black tip."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Red wattles in front of the eyes",
#        "edge": "The Red-wattled Lapwing sports red wattles in front of its eyes."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "White patch that runs down the cheeks to the underparts",
#        "edge": "The Red-wattled Lapwing has a white patch that runs down its cheeks and reaches the underparts."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Black flight feathers",
#        "edge": "When in flight, the Red-wattled Lapwing has black flight feathers."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "White wing patch",
#        "edge": "The Red-wattled Lapwing has a white wing patch."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Usually found in small groups around water bodies, agricultural fields, and dry land",
#        "edge": "The Red-wattled Lapwing is usually found in small groups around water bodies, agricultural fields, and dry land."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Primarily on insects",
#        "edge": "The Red-wattled Lapwing feeds primarily on insects."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Typical plover like manner",
#        "edge": "The Red-wattled Lapwing catches food in a typical plover-like manner."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Loud alarm call",
#        "edge": "The Red-wattled Lapwing is known for its loud alarm call."
#    },
#    {
#        "node_1": "Red-wattled Lapwing",
#        "node_2": "Often compared to the words ‘Did we do it?’",
#        "edge": "The loud alarm call of the Red-wattled Lapwing is often compared to the words 'Did we do it?'."
#    }
# ] [
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Species",
#        "edge": "The White-tailed Lapwing is a species."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Elegant",
#        "edge": "The White-tailed Lapwing is described as elegant."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Small",
#        "edge": "The White-tailed Lapwing is rather small."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Pale sandy-brown",
#        "edge": "The overall color of the White-tailed Lapwing is pale sandy-brown."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Long legs",
#        "edge": "The White-tailed Lapwing has long, bright yellow legs."
#    },
#    {
#        "node_1": "In flight",
#        "node_2": "Striking tri-colored wing pattern",
#        "edge": "When in flight, a striking tri-colored wing pattern of brown, black, and white is exposed on the White-tailed Lapwing."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Sociable Lapwing",
#        "edge": "The White-tailed Lapwing is somewhat similar to the Sociable Lapwing."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Black-tipped tail",
#        "edge": "In contrast, the Sociable Lapwing has a black-tipped tail, while the White-tailed Lapwing's tail is all-white."
#    },
#    {
#        "node_1": "White-tailed Lapwing",
#        "node_2": "Heavily vegetated wetlands",
#        "edge": "The White-tailed Lapwing is often seen in heavily vegetated wetlands."
#    }
# ] [
#    {
#        "node_1": "Painted Stork",
#        "node_2": "Stork",
#        "edge": "The Painted Stork is a type of stork."
#    },
#    {
#        "node_1": "Painted Stork",
#        "node_2": "Large",
#        "edge": "The Painted Stork is described as large in the context."
#    },
#    {
#        "node_1": "Painted Stork",
#        "node_2": "Adult",
#        "edge": "In the context, Adult refers to the matured form of the Painted Stork, primarily white with specific features."
#    },
#    {
#        "node_1": "Adult Painted Stork",
#        "node_2": "Black striped markings on the wings",
#        "edge": "The adult Painted Stork has black striped markings on its wings."
#    },
#    {
#        "node_1": "Adult Painted Stork",
#        "node_2": "Bright pink on tertials",
#        "edge": "The adult Painted Stork has bright pink color on its tertials."
#    },
#    {
#        "node_1": "Adult Painted Stork",
#        "node_2": "Bright orange face",
#        "edge": "The adult Painted Stork has a bright orange face."
#    },
#    {
#        "node_1": "Adult Painted Stork",
#        "node_2": "Pinkish legs",
#        "edge": "The adult Painted Stork has pinkish legs."
#    },
#    {
#        "node_1": "Adult Painted Stork",
#        "node_2": "Speckled band across the chest",
#        "edge": "The adult Painted Stork has a speckled band across its chest."
#    },
#    {
#        "node_1": "Immatures",
#        "node_2": "Painted Stork",
#        "edge": "Immatures refer to the young, inexperienced form of the Painted Stork, which is duller and lacks certain features."
#    },
#    {
#        "node_1": "Immature Painted Stork",
#        "node_2": "Brown wash",
#        "edge": "The immature Painted Stork has a brown wash."
#    },
#    {
#        "node_1": "Fly",
#        "node_2": "Painted Stork",
#        "edge": "The Painted Stork flies when moving from one location to another."
#    },
#    {
#        "node_1": "Painted Stork",
#        "node_2": "Head and neck drooping almost at or below the belly level",
#        "edge": "When flying, the head and neck of the Painted Stork often droop almost at or below the belly level."
#    },
#    {
#        "node_1": "Painted Stork",
#        "node_2": "Water bodies",
#        "edge": "The Painted Stork is typically seen near water bodies such as wetlands, marshes, and flooded agricultural fields."
#    }
# ] [
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "waterbird",
#        "edge": "The Little Cormorant is a type of waterbird."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "ducklike",
#        "edge": "The Little Cormorant is ducklike in appearance."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "all black",
#        "edge": "The Little Cormorant has an all black coloration."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "flattish head",
#        "edge": "The head of the Little Cormorant is flattish in shape."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "sharply hooked bill",
#        "edge": "The bill of the Little Cormorant is sharply hooked at the tip."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "smallest of the cormorants found in the region",
#        "edge": "The Little Cormorant is the smallest of the cormorants found in the given region."
#    },
#    {
#        "node_1": "Little Cormorant (breeding adult)",
#        "node_2": "white plumes on the sides of the head",
#        "edge": "Breeding adults of the Little Cormorant have white plumes on the sides of their heads."
#    },
#    {
#        "node_1": "Little Cormorant (breeding adult)",
#        "node_2": "stouter bill",
#        "edge": "The stouter bill is a characteristic feature of breeding adults of the Little Cormorant."
#    },
#    {
#        "node_1": "Little Cormorant (breeding adult)",
#        "node_2": "flat on Little Cormorant",
#        "edge": "The shape of the head of breeding adults of the Little Cormorant is flat."
#    },
#    {
#        "node_1": "Indian Cormorant",
#        "node_2": "Little Cormorant",
#        "edge": "The Indian Cormorant and the Little Cormorant are similar, but the Little Cormorant is smaller in size, has a stouter bill, and a flat head compared to the rounded head of the Indian Cormorant."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "frequently seen swimming",
#        "edge": "The Little Cormorant is frequently seen swimming in water bodies."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "head and neck pointing upward",
#        "edge": "When swimming, the head and neck of the Little Cormorant are typically pointing upward."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "suddenly disappearing underwater",
#        "edge": "While swimming, the Little Cormorant suddenly disappears underwater to catch fish."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "often perches upright on a rock",
#        "edge": "The Little Cormorant often perches upright on rocks."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "drying itself with outstretched wings",
#        "edge": "After perching, the Little Cormorant dries itself by spreading its wings."
#    },
#    {
#        "node_1": "Little Cormorant",
#        "node_2": "inland water bodies",
#        "edge": "The Little Cormorant is often seen in small groups in inland water bodies."
#    },
#    {
#        "node_1": "cormorants",
#        "node_2": "waterbirds",
#        "edge": "Cormorants are a type of waterbird."
#    }
# ] [
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Cormorant",
#        "edge": "The Great Cormorant is a specific type of cormorant."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Large size",
#        "edge": "The Great Cormorant is large in size."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "White patch on throat",
#        "edge": "The Great Cormorant has a white patch on its throat."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Lack of crest",
#        "edge": "The Great Cormorant does not have a crest."
#    },
#    {
#        "node_1": "Breeding adults",
#        "node_2": "Great Cormorant",
#        "edge": "Breeding adults refer to adult Great Cormorants."
#    },
#    {
#        "node_1": "Breeding adults",
#        "node_2": "Circular white patch on flanks",
#        "edge": "Breeding Great Cormorants show a circular white patch on their flanks."
#    },
#    {
#        "node_1": "Immatures",
#        "node_2": "Great Cormorant",
#        "edge": "Immature Great Cormorants refer to young or less mature Great Cormorants."
#    },
#    {
#        "node_1": "Immatures",
#        "node_2": "Contrasting white belly",
#        "edge": "Immature Great Cormorants typically have a contrasting white belly."
#    },
#    {
#        "node_1": "African 'White-breasted'",
#        "node_2": "Great Cormorant",
#        "edge": "The African 'White-breasted' is a specific subspecies of the Great Cormorant."
#    },
#    {
#        "node_1": "African 'White-breasted'",
#        "node_2": "Extensive white underparts",
#        "edge": "The African 'White-breasted' Great Cormorant has extensive white underparts in all plumages."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Standing on rocks or pilings",
#        "edge": "The Great Cormorant is often spotted standing on rocks or pilings."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Dives frequently",
#        "edge": "The Great Cormorant dives frequently."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Feeding on fish",
#        "edge": "The Great Cormorant feeds on fish."
#    },
#    {
#        "node_1": "Great Cormorant",
#        "node_2": "Many types of water bodies",
#        "edge": "The Great Cormorant can be found in many types of water bodies, such as rivers, reservoirs, and marine environments."
#    },
#    {
#        "node_1": "In North America",
#        "node_2": "Great Cormorant",
#        "edge": "In North America, the Great Cormorant is restricted to coastal North Atlantic waters."
#    }
# ] [
#    {
#        "node_1": "Indian Pond-Heron",
#        "node_2": "Species",
#        "edge": "The Indian Pond-Heron is identified as a species in the given context."
#    },
#    {
#        "node_1": "Indian Pond-Heron",
#        "node_2": "Aquatic habitat",
#        "edge": "The Indian Pond-Heron is common in most aquatic habitats across the Indian subcontinent."
#    },
#    {
#        "node_1": "Adults (Indian Pond-Heron)",
#        "node_2": "Breeding plumage",
#        "edge": "During breeding, adults of the Indian Pond-Herons have a dark reddish brown back that contrasts with a yellowish head, neck, and breast."
#    },
#    {
#        "node_1": "Non-breeding adults (Indian Pond-Heron)",
# ...
#     },
#     {
#         "node_1": "Barn Owl",
#         "node_2": "Bone-chilling, rising shriek",
#         "edge": "The call of the Barn Owl is a bone-chilling, rising shriek."
#     }
# ] [
#    {
#        "node_1": "Yellow-wattled Lapwing",
#        "node_2": "Species",
#        "edge": "The Yellow-wattled Lapwing is a species of bird."
#    },
#    {
#        "node_1": "Elegantly long-winged brown lapwing",
#        "node_2": "Description",
#        "edge": "The Yellow-wattled Lapwing is elegantly long-winged and has a brown body."
#    },
#    {
#        "node_1": "Breeding adult",
#        "node_2": "Appearance",
#        "edge": "A breeding adult of the Yellow-wattled Lapwing has a clean black cap, bright yellow facial wattles, and a white belly."
#    },
#    {
#        "node_1": "Non-breeding adults and juveniles",
#        "node_2": "Appearance",
#        "edge": "Non-breeding adults and juveniles of the Yellow-wattled Lapwing are more mottled overall and lack a solid black cap."
#    },
#    {
#        "node_1": "White belly",
#        "node_2": "Appearance",
#        "edge": "A breeding adult of the Yellow-wattled Lapwing has a white belly."
#    },
#    {
#        "node_1": "Contrasting wing and tail pattern",
#        "node_2": "Flight Characteristics",
#        "edge": "The note contrasting wing and tail pattern is noticeable when the Yellow-wattled Lapwing is in flight."
#    },
#    {
#        "node_1": "Dry open areas",
#        "node_2": "Habitat",
#        "edge": "The Yellow-wattled Lapwing prefers dry open areas."
#    },
#    {
#        "node_1": "Away from water",
#        "node_2": "Habitat",
#        "edge": "The Yellow-wattled Lapwing often chooses habitats that are well away from water."
#    },
#    {
#        "node_1": "Tern-like call",
#        "node_2": "Vocalization",
#        "edge": "The Yellow-wattled Lapwing gives a loud rasping tern-like call."
#    },
#    {
#        "node_1": "Loud ‘cheeeee’it' in alarm",
#        "node_2": "Vocalization",
#        "edge": "In alarm, the Yellow-wattled Lapwing makes a loud ‘cheeeee’it' sound."
#    },
#    {
#        "node_1": "Generally not as noisy as other lapwings",
#        "node_2": "Behavior",
#        "edge": "Compared to other lapwings, the Yellow-wattled Lapwing is generally not as noisy."
#    }
# ] [
#    {
#        "node_1": "Asian Koel",
#        "node_2": "Large cuckoo",
#        "edge": "The Asian Koel is a type of large cuckoo."
#    },
#    {
#        "node_1": "Asian Koel",
#        "node_2": "Distinctive",
#        "edge": "The Asian Koel is distinctive in all plumages."
#    },
#    {
#        "node_1": "Asian Koel",
#        "node_2": "Secretive",
#        "edge": "The Asian Koel keeps to the interior of dense trees and is secretive."
#    },
#    {
#        "node_1": "Asian Koel",
#        "node_2": "Inhabitant",
#        "edge": "The Asian Koel can be found in many habitats, including inner cities and fields."
#    },
#    {
#        "node_1": "Adult males Asian Koel",
#        "node_2": "Glossy black",
#        "edge": "Adult male Asian Koels are glossy black."
#    },
#    {
#        "node_1": "Adult males Asian Koel",
#        "node_2": "Dull lime-green bill",
#        "edge": "The bills of adult male Asian Koels are dull lime-green."
#    },
#    {
#        "node_1": "Females and immatures Asian Koel",
#        "node_2": "Blackish brown",
#        "edge": "Female and immature Asian Koels are blackish brown."
#    },
#    {
#        "node_1": "Females and immatures Asian Koel",
#        "node_2": "White dots on the wings",
#        "edge": "Female and immature Asian Koels have white dots on their wings."
#    },
#    {
#        "node_1": "Females and immatures Asian Koel",
#        "node_2": "Strong streaking on head and throat",
#        "edge": "Female and immature Asian Koels have strong streaking on their head and throat."
#    },
#    {
#        "node_1": "Adults Asian Koel",
#        "node_2": "Ruby-red eyes",
#        "edge": "Adult Asian Koels have ruby-red eyes."
#    },
#    {
#        "node_1": "Females",
#        "node_2": "Lay eggs in the nests of other large birds",
#        "edge": "Female Asian Koels lay eggs in the nests of other large birds, including crows, shrikes, and starlings."
#    },
#    {
#        "node_1": "Adult males Asian Koel",
#        "node_2": "Loud, persistent ‘ko-EL!’",
#        "edge": "The song of an adult male Asian Koel is a loud, persistent ‘ko-EL!’ similar to a peacock’s call."
#    }
# ] [
#    {
#        "node_1": "Gray-throated Martin",
#        "node_2": "Species",
#        "edge": "The Gray-throated Martin is a species of bird."
#    },
#    {
#        "node_1": "Gray-throated Martin",
#        "node_2": "Small gray-brown swallow",
#        "edge": "The Gray-throated Martin is a small, gray-brown swallow."
#    },
#    {
#        "node_1": "Gray-throated Martin",
#        "node_2": "Pale white underparts",
#        "edge": "The underside of the Gray-throated Martin is pale white."
#    },
#    {
#        "node_1": "Gray-throated Martin",
#        "node_2": "Gray-brown chin, throat, and upper breast",
#        "edge": "The Gray-throated Martin has a gray-brown chin, throat, and upper breast."
#    },
#    {
#        "node_1": "Gray-throated Martin",
#        "node_2": "Does not show any kind of breast band",
#        "edge": "The Gray-throated Martin does not have a visible breast band."
#    },
#    {
#        "node_1": "Tail",
#        "node_2": "Gray-throated Martin",
#        "edge": "The tail of the Gray-throated Martin is short, square-ended or sometimes marginally forked."
#    },
#    {
#        "node_1": "Location",
#        "node_2": "Slow-flowing rivers, lakes, wet grasslands, and other wetland habitats",
#        "edge": "The Gray-throated Martin is mainly found in slow-flowing rivers, lakes, wet grasslands, and other wetland habitats."
#    },
#    {
#        "node_1": "Gray-throated Martin",
#        "node_2": "Mostly seen in the air",
#        "edge": "The Gray-throated Martin is often seen flying or in flight."
#    },
#    {
#        "node_1": "Location",
#        "node_2": "Wires",
#        "edge": "The Gray-throated Martin can be seen sitting on wires."
#    },
#    {
#        "node_1": "Location",
#        "node_2": "On the ground or on cliffs while breeding",
#        "edge": "During its breeding period, the Gray-throated Martin may be seen on the ground or on cliffs."
#    }
# ] [
#    {
#        "node_1": "Red-crested Pochard",
#        "node_2": "Species",
#        "edge": "The Red-crested Pochard is a species of duck."
#    },
#    {
#        "node_1": "Red-crested Pochard",
#        "node_2": "Diving Duck",
#        "edge": "The Red-crested Pochard is a diving duck, which means it submerges to find food underwater."
#    },
#    {
#        "node_1": "Red-crested Pochard",
#        "node_2": "Larger Lakes and Reservoirs",
#        "edge": "The Red-crested Pochard inhabits larger lakes and reservoirs."
#    },
#    {
#        "node_1": "Red-crested Pochard",
#        "node_2": "Fringing Reeds",
#        "edge": "The Red-crested Pochard is often found near fringing reeds."
#    },
#    {
#        "node_1": "Male (Red-crested Pochard)",
#        "node_2": "Striking and Unmistakable",
#        "edge": "The male Red-crested Pochard is striking and unmistakable due to its large, rounded, rusty-orange head, long red bill, and black breast."
#    },
#    {
#        "node_1": "Female (Red-crested Pochard)",
#        "node_2": "Drab",
#        "edge": "The female Red-crested Pochard is rather drab in appearance."
#    },
#    {
#        "node_1": "Female (Red-crested Pochard)",
#        "node_2": "Distinctive",
#        "edge": "Despite being drab, the female Red-crested Pochard is still distinctive due to its dirty buff overall, pale cheeks, dark face, and rounded brown cap."
#    },
#    {
#        "node_1": "In Flight (Red-crest Pochard)",
#        "node_2": "Thick White Wing Stripe",
#        "edge": "When in flight, both sexes of the Red-crested Pochard show a thick white wing stripe."
#    },
#    {
#        "node_1": "In Flight (Red-crest Pochard)",
#        "node_2": "Whitish Underwings",
#        "edge": "When in flight, both sexes of the Red-crested Pochard also show whitish underwings."
#    },
#    {
#        "node_1": "Red-crested Pochard",
#        "node_2": "Waterfowl Collection",
#        "edge": "The Red-crested Pochard is a common feature of waterfowl collections in European town and city parks."
#    }
# ] [
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Species",
#         "edge": "The Tufted Duck is a species of duck."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Wetlands",
#         "edge": "The Tufted Duck is common in wetlands such as marshy and reed-fringed lakes, open reservoirs, and during winter, on the sea."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Open Reservoirs",
#         "edge": "The Tufted Duck is common in open reservoirs."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Marshy Lakes",
#         "edge": "The Tufted Duck is common in marshy lakes."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Reed-fringed Lakes",
#         "edge": "The Tufted Duck is common in reed-fringed lakes."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Sea",
#         "edge": "During winter, the Tufted Duck can be found on the sea."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Lakes (freezing)",
#         "edge": "During winter, when lakes freeze, the Tufted Duck might move to the sea."
#     },
#     {
#         "node_1": "Male Tufted Duck",
#         "node_2": "Tufted Duck",
#         "edge": "The Male Tufted Duck is a distinctive sub-species of the Tufted Duck."
#     },
#     {
#         "node_1": "Male Tufted Duck",
#         "node_2": "Black overall",
#         "edge": "The male Tufted Duck has black overall coloration."
#     },
#     {
#         "node_1": "Male Tufted Duck",
#         "node_2": "Bright white flanks",
#         "edge": "The male Tufted Duck has bright white flanks."
#     },
#     {
#         "node_1": "Male Tufted Duck",
#         "node_2": "Floppy crest",
#         "edge": "The male Tufted Duck has a floppy crest."
#     },
#     {
#         "node_1": "Male Tufted Duck",
#         "node_2": "White flanks (whiter than scaup)",
#         "edge": "The white flanks of the male Tufted Duck are whiter than those of the scaup."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Tufted Duck",
#         "edge": "The Female Tufted Duck is a sub-species of the Tufted Duck."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Dark brown overall",
#         "edge": "The female Tufted Duck has dark brown overall coloration."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Short crest",
#         "edge": "The female Tufted Duck has a short crest."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Paler flanks",
#         "edge": "The female Tufted Duck has paler flanks compared to the male."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Golden-yellow eyes",
#         "edge": "The female Tufted Duck has staring golden-yellow eyes."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Messy white patch at base of bill",
#         "edge": "The female Tufted Duck often has a messy white patch at the base of its bill."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Darker than scaup",
#         "edge": "Even nearly tuftless females are darker than scaup."
#     },
#     {
#         "node_1": "Female Tufted Duck",
#         "node_2": "Limited white patch on face",
#         "edge": "The limited white patch on the face of the female Tufted Duck is less than that of the scaup."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Scaup",
#         "edge": "The Tufted Duck is often found among flocks of scaup."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Vagrants to North America",
#         "edge": "Rare winter vagrants to North America are usually found singly among flocks of scaup."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Blackish back",
#         "edge": "The Tufted Duck always shows a very dark blackish back compared to the scaup."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Tuftless females",
#         "edge": "Even nearly tuftless females of the Tufted Duck are darker than scaup with more limited white patch on face."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Diving",
#         "edge": "The Tufted Duck feeds by diving."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Feeding",
#         "edge": "The Tufted Duck feeds on its diet, which is not specified in the text."
#     },
#     {
#         "node_1": "Tufted Duck",
#         "node_2": "Diet",
#         "edge": "The diet of the Tufted Duck is not specified in the text."
#     }
# ] [
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "dove",
#        "edge": "The Oriental Turtle-Dove is a type of dove."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "rufous-scaled scapulars",
#        "edge": "The Oriental Turtle-Dove has rufous-scaled scapulars."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "wing coverts",
#        "edge": "The Oriental Turtle-Dove has wing coverts."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "dusky underparts",
#        "edge": "The underside of the Oriental Turtle-Dove is dusky in color."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "black-and-white striped patch",
#        "edge": "The side of the Oriental Turtle-Dove's neck has a black-and-white striped patch."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "silver-tipped feathers",
#        "edge": "The silver-tipped feathers are part of the black-and-white striped patch on the side of the Oriental Turtle-Dove's neck."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "considerable variation in plumage",
#        "edge": "There is a considerable variation in the plumage of different subspecies of Oriental Turtle-Dove."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "resident",
#        "edge": "The southernmost populations of Oriental Turtle-Dove are resident."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "migrate down south during winter",
#        "edge": "The other populations of Oriental Turtle-Dove migrate down south during the winter."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "open lowland woods and copses with rich undergrowth",
#        "edge": "The Oriental Turtle-Dove breeds in open lowland woods and copses with rich undergrowth."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "shy",
#        "edge": "The Oriental Turtle-Dove is rather shy."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "tree canopy",
#        "edge": "The Oriental Turtle-Dove keeps well hidden in the tree canopy."
#    },
#    {
#        "node_1": "Oriental Turtle-Dove",
#        "node_2": "two hoarse notes followed by two clear notes 'hr-hr oo-oo'",
#        "edge": "The call of the Oriental Turtle-Dove consists of two hoarse notes followed by two clear notes, 'hr-hr oo-oo'."
#    }
# ](1207, 5)
#               node_1                            node_2  \
# 0  common tailorbird                  warblerlike bird
# 1  common tailorbird                        green back
# 2  common tailorbird                     reddish crown
# 3  common tailorbird                         long bill
# 4  common tailorbird  parks, gardens, and wooded areas
#
#                                                 edge  \
# 0       The Common Tailorbird is a warblerlike bird.
# 1            The Common Tailorbird has a green back.
# 2         The Common Tailorbird has a reddish crown.
# 3             The Common Tailorbird has a long bill.
# 4  The Common Tailorbird is an inhabitant of park...
#
#                            chunk_id  count
# 0  9ad3f5260d19447388f177864213431a      4
# 1  9ad3f5260d19447388f177864213431a      4
# 2  9ad3f5260d19447388f177864213431a      4
# 3  9ad3f5260d19447388f177864213431a      4
# 4  9ad3f5260d19447388f177864213431a      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                  node_1                       node_2  \
# 26337            yellow-wattled lapwing                 vocalization
# 26341  yellowish feet (golden slippers)  breeding adult little egret
# 26344  yellowish feet (golden slippers)                 little egret
# 26353               zebra-striped wings              eurasian hoopoe
# 26366                       zwee! calls             indian white-eye
#
#                                                 chunk_id  count  \
# 26337  a5d8944eebdf453785ae4bbec9ba0309,a5d8944eebdf4...      2
# 26341  a28314cd80e24dc8bda647596c9aefdb,a28314cd80e24...      2
# 26344  a28314cd80e24dc8bda647596c9aefdb,a28314cd80e24...     10
# 26353  e30e2d93a6194996b9c06e4aef6473d9,e30e2d93a6194...     10
# 26366  131a43367f8a41cb850d5d325732150f,131a43367f8a4...     12
#
#                        edge
# 26337  contextual proximity
# 26341  contextual proximity
# 26344  contextual proximity
# 26353  contextual proximity
# 26366  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                 node_1                       node_2  \
# 0             2 long wispy head plumes  breeding adult little egret
# 1             2 long wispy head plumes                 little egret
# 2                      absence of blue                   bluethroat
# 3                             activity                        calls
# 4                             activity                        color
# ...                                ...                          ...
# 6826            yellow-wattled lapwing                 vocalization
# 6827  yellowish feet (golden slippers)  breeding adult little egret
# 6828  yellowish feet (golden slippers)                 little egret
# 6829               zebra-striped wings              eurasian hoopoe
# 6830                       zwee! calls             indian white-eye
#
#                                                chunk_id                  edge  \
# 0     a28314cd80e24dc8bda647596c9aefdb,a28314cd80e24...  contextual proximity
# 1     a28314cd80e24dc8bda647596c9aefdb,a28314cd80e24...  contextual proximity
# 2     2162f35ac20b45a6adff6fc31a9ff675,2162f35ac20b4...  contextual proximity
# 3     dfbf1312e1134629ac4d830dca56d2c9,dfbf1312e1134...  contextual proximity
# 4     dfbf1312e1134629ac4d830dca56d2c9,dfbf1312e1134...  contextual proximity
# ...                                                 ...                   ...
# 6826  a5d8944eebdf453785ae4bbec9ba0309,a5d8944eebdf4...  contextual proximity
# 6827  a28314cd80e24dc8bda647596c9aefdb,a28314cd80e24...  contextual proximity
# 6828  a28314cd80e24dc8bda647596c9aefdb,a28314cd80e24...  contextual proximity
# 6829  e30e2d93a6194996b9c06e4aef6473d9,e30e2d93a6194...  contextual proximity
# 6830  131a43367f8a41cb850d5d325732150f,131a43367f8a4...  contextual proximity
#
#       count
# 0         2
# 1        10
# 2         6
# 3         2
# 4         4
# ...     ...
# 6826      2
# 6827      2
# 6828     10
# 6829     10
# 6830     12
#
# [6831 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (1334,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  8
# [['2 long wispy head plumes', 'blackish legs', 'breeding adult little egret', 'compare with larger great and intermediate egrets, stockier cattle egret, and white morph reef herons', 'distinctive within its range', 'little egret', 'nests and roosts communally', 'occurs as singles or small loose groups', 'slender dark bill', 'small fish', 'small snow-white heron', 'spray of white plumes (aigrettes)', 'wetlands (lakes, rivers, marshes, estuaries)', 'yellowish feet (golden slippers)'], ['absence of blue', 'bluethroat', 'bluethroat (breeds)', 'bluethroat (even the dullest young females)', 'bluethroat (females lacking blue entirely)', 'bluethroat (females)', 'bluethroat (head-on view)', 'bluethroat (singing males)', 'bluethroat (variable song)', 'bluethroat (winters)', 'bold white eyebrow and throat, necklace of dark streaks, rufous on the base of the tail', 'conspicuous perch', 'dull gray (above)', 'edge areas', 'electric blue and orange', 'europe and asia into alaska', 'fainter colors', 'imitations of other species', 'northern africa to southeast asia', 'scrubby, brushy habitat', 'stays hidden', 'thrush-like'], ['activity', 'adaptable', 'additional features of western marsh harrier', 'adult', 'adult male', 'adult male shikra', 'adult males asian koel', 'adult painted stork', 'adult white-breasted waterhen', 'adults', 'adults (indian pond-heron)', 'adults asian koel', 'africa', 'africa and southern asia', "african 'white-breasted'", 'aggressive', 'aggressive towards other birds', 'aggressively territorial', 'agricultural fields', 'agricultural land', 'agricultural lands with scattered woods', 'agricultural landscapes', 'all black', 'all habitats', 'alpine shrubbery', 'also in russia', 'also mimics other birds', 'also regularly walks around', 'alternate name', 'american wigeon', 'among the most common species', 'amur stonechat', 'appearance', 'appearance (female)', 'appearance (immature)', 'appearance (male)', 'aquatic habitat', 'ash-brown colored babbler', 'ashy prinia', 'asia', 'asian koel', 'associates readily with other ducks', 'associates with', 'association', 'australia', 'avoids woodlands', 'away from water', 'bank myna', 'bar-headed goose', 'bar-headed goose (in flight)', 'bare ground near water', 'bare, deep orange patch around its eye', 'barring on its tail', 'bays', 'beautifully vivid turquoise-blue', 'behavior', 'behavior and diet of pied avocet', 'behavior of pied avocet', 'behavior of western marsh harrier', 'behavior of wood sandpiper', 'behavioral context of calling in black-winged stilt', 'bi-colored bill', 'bicolored', 'big feet', 'big pinkish-orange bill', 'big white eyebrow on dark brown head', 'big white forewing patches', 'big white oval patches', 'bill', 'bill color', 'bird', 'black (central and southern asia)', 'black bib', 'black bill', 'black collar', 'black crest', 'black drongo', "black drongo's calls", "black drongo's plumage", 'black face and throat', 'black head', 'black legs', 'black lump', 'black overall', 'black rear end', 'black redstart', 'black striped markings on the wings', 'black upperparts', 'black with a white vent and a white wing patch', 'black-and-brown', 'black-and-white plumage (males)', 'black-pointed tail', 'black-tipped tail', 'black-winged kite', 'black-winged stilt', 'blackish', 'blackish back', 'blackish brown', 'blackish-gray bill', 'blue-gray above', 'blue-gray with white eyebrow (central and southwest europe)', 'bluish-green sheen', 'bluish-purple', 'blyth’s pipit', 'bobs tail when nervous', 'bogs and marshes', 'bold and fearless', 'bold black-and-white head and neck pattern', 'boldly pied plumage', 'booted and sykes’s warbler', 'both shikras (males and females)', 'brackish habitats', 'brackish marshes', 'breeding adult', 'breeding adults', 'breeding at northern latitudes', 'breeding birds', 'breeding colonies of great egret', 'breeding female', 'breeding ground', 'breeding male', 'breeding male (siberian stonechat)', 'breeding male (taiga flycatcher)', 'breeding males', 'bree ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                    node    color  group
# 0                              2 long wispy head plumes  #91db57      1
# 1                                         blackish legs  #91db57      1
# 2                           breeding adult little egret  #91db57      1
# 3     compare with larger great and intermediate egr...  #91db57      1
# 4                          distinctive within its range  #91db57      1
# ...                                                 ...      ...    ...
# 1329                                                shy  #57db80      8
# 1330                             silver-tipped feathers  #57db80      8
# 1331                                        tree canopy  #57db80      8
# 1332  two hoarse notes followed by two clear notes '...  #57db80      8
# 1333                                       wing coverts  #57db80      8
#
# [1334 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
